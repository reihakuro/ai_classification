# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


if not os.path.exists("ai_classification"):

    # !git clone -q https://github.com/reihakuro/ai_classification.git > /dev/null 2>&1

# %cd /kaggle/working/ai_classification


# !mkdir -p data/raw 


# !cp -r /kaggle/input/datasets/trungkientrungkien/faceclassificationdataset/data/raw/. data/raw/ > /dev/null 2>&1


# !pip install -qq -r requirements.txt > /dev/null 2>&1

# !make all
# Out:
# /kaggle/working/ai_classification
#  Preprocessing data...
# python src/data_prep/split_data.py
# [*] Bắt đầu chia dữ liệu từ /kaggle/working/ai_classification/data/raw sang /kaggle/working/ai_classification/data/dataset_split...
# [+] Khang: 500 images -> Train: 350 | Val: 75 | Test: 75
# [+] Phuc: 500 images -> Train: 350 | Val: 75 | Test: 75
# [+] Kien: 500 images -> Train: 350 | Val: 75 | Test: 75
# [+] Tu: 500 images -> Train: 350 | Val: 75 | Test: 75
#
# Split data completed successfully!
#  Training model 20260413_144919...
# python src/train/train_tf_cnn.py --version 20260413_144919
# Loading datasets...
# Found 1400 files belonging to 4 classes.
# Found 300 files belonging to 4 classes.
# Found 300 files belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "FaceNet_MobileNetV2_Final"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augment (Sequential)            │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_160            │ (None, 5, 5, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,263,108 (8.63 MB)
#  Trainable params: 1,866,564 (7.12 MB)
#  Non-trainable params: 396,544 (1.51 MB)
#
# Training...
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.6183 - loss: 0.9332
# Epoch 1: val_accuracy improved from None to 0.68000, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 1: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 56s 921ms/step - accuracy: 0.8043 - loss: 0.5088 - val_accuracy: 0.6800 - val_loss: 0.7316 - learning_rate: 1.0000e-04
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.9889 - loss: 0.0661
# Epoch 2: val_accuracy improved from 0.68000 to 0.80667, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 2: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 894ms/step - accuracy: 0.9907 - loss: 0.0559 - val_accuracy: 0.8067 - val_loss: 0.4955 - learning_rate: 1.0000e-04
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.9963 - loss: 0.0297
# Epoch 3: val_accuracy improved from 0.80667 to 0.83667, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 3: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 894ms/step - accuracy: 0.9943 - loss: 0.0299 - val_accuracy: 0.8367 - val_loss: 0.4125 - learning_rate: 1.0000e-04
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9989 - loss: 0.0149
# Epoch 4: val_accuracy improved from 0.83667 to 0.91000, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 4: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 872ms/step - accuracy: 0.9986 - loss: 0.0148 - val_accuracy: 0.9100 - val_loss: 0.3191 - learning_rate: 1.0000e-04
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.9997 - loss: 0.0090
# Epoch 5: val_accuracy improved from 0.91000 to 0.92333, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 5: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 861ms/step - accuracy: 0.9993 - loss: 0.0090 - val_accuracy: 0.9233 - val_loss: 0.2869 - learning_rate: 1.0000e-04
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.9989 - loss: 0.0095
# Epoch 6: val_accuracy did not improve from 0.92333
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 37s 839ms/step - accuracy: 0.9979 - loss: 0.0109 - val_accuracy: 0.9033 - val_loss: 0.3061 - learning_rate: 1.0000e-04
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.9998 - loss: 0.0042
# Epoch 7: val_accuracy improved from 0.92333 to 0.95667, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 7: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 41s 847ms/step - accuracy: 0.9993 - loss: 0.0056 - val_accuracy: 0.9567 - val_loss: 0.2192 - learning_rate: 1.0000e-04
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.9992 - loss: 0.0068
# Epoch 8: val_accuracy did not improve from 0.95667
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 36s 823ms/step - accuracy: 0.9986 - loss: 0.0066 - val_accuracy: 0.9367 - val_loss: 0.2397 - learning_rate: 1.0000e-04
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.9986 - loss: 0.0086
# Epoch 9: val_accuracy improved from 0.95667 to 0.96333, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 9: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 47s 971ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9633 - val_loss: 0.1580 - learning_rate: 1.0000e-04
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 10: val_accuracy improved from 0.96333 to 0.97333, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 10: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 920ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9733 - val_loss: 0.1227 - learning_rate: 1.0000e-04
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - accuracy: 0.9997 - loss: 0.0016
# Epoch 11: val_accuracy improved from 0.97333 to 0.98000, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 11: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 860ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9800 - val_loss: 0.0936 - learning_rate: 1.0000e-04
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - accuracy: 0.9997 - loss: 0.0025
# Epoch 12: val_accuracy did not improve from 0.98000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 37s 850ms/step - accuracy: 0.9993 - loss: 0.0038 - val_accuracy: 0.9633 - val_loss: 0.1377 - learning_rate: 1.0000e-04
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 13: val_accuracy did not improve from 0.98000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 860ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9733 - val_loss: 0.1210 - learning_rate: 1.0000e-04
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 14: val_accuracy did not improve from 0.98000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 37s 848ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9767 - val_loss: 0.0807 - learning_rate: 1.0000e-04
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 15: val_accuracy did not improve from 0.98000
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9733 - val_loss: 0.1087 - learning_rate: 1.0000e-04
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9993 - loss: 0.0020
# Epoch 16: val_accuracy did not improve from 0.98000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 892ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9700 - val_loss: 0.1092 - learning_rate: 5.0000e-05
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 17: val_accuracy did not improve from 0.98000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 906ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9733 - val_loss: 0.0893 - learning_rate: 5.0000e-05
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 18: val_accuracy improved from 0.98000 to 0.98333, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 18: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 908ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9833 - val_loss: 0.0677 - learning_rate: 5.0000e-05
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 778ms/step - accuracy: 1.0000 - loss: 8.3604e-04
# Epoch 19: val_accuracy did not improve from 0.98333
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 897ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9833 - val_loss: 0.0607 - learning_rate: 5.0000e-05
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 784ms/step - accuracy: 0.9997 - loss: 0.0011
# Epoch 20: val_accuracy did not improve from 0.98333
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 879ms/step - accuracy: 0.9993 - loss: 0.0032 - val_accuracy: 0.9833 - val_loss: 0.0565 - learning_rate: 5.0000e-05
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 21: val_accuracy did not improve from 0.98333
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 887ms/step - accuracy: 1.0000 - loss: 9.9963e-04 - val_accuracy: 0.9833 - val_loss: 0.0507 - learning_rate: 5.0000e-05
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 780ms/step - accuracy: 1.0000 - loss: 9.1820e-04
# Epoch 22: val_accuracy did not improve from 0.98333
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 870ms/step - accuracy: 1.0000 - loss: 6.7371e-04 - val_accuracy: 0.9833 - val_loss: 0.0429 - learning_rate: 5.0000e-05
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 1.0000 - loss: 9.0810e-04
# Epoch 23: val_accuracy improved from 0.98333 to 0.98667, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 23: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 40s 903ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9867 - val_loss: 0.0332 - learning_rate: 2.5000e-05
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 1.0000 - loss: 7.1474e-04
# Epoch 24: val_accuracy did not improve from 0.98667
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 896ms/step - accuracy: 1.0000 - loss: 6.1203e-04 - val_accuracy: 0.9867 - val_loss: 0.0255 - learning_rate: 2.5000e-05
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 780ms/step - accuracy: 1.0000 - loss: 7.4246e-04
# Epoch 25: val_accuracy improved from 0.98667 to 0.99000, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 25: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 886ms/step - accuracy: 1.0000 - loss: 8.8392e-04 - val_accuracy: 0.9900 - val_loss: 0.0211 - learning_rate: 2.5000e-05
# Epoch 26/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 773ms/step - accuracy: 1.0000 - loss: 5.7440e-04
# Epoch 26: val_accuracy improved from 0.99000 to 0.99333, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 26: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 875ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9933 - val_loss: 0.0172 - learning_rate: 2.5000e-05
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 27: val_accuracy did not improve from 0.99333
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 36s 830ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9933 - val_loss: 0.0129 - learning_rate: 2.5000e-05
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 28: val_accuracy improved from 0.99333 to 1.00000, saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
#
# Epoch 28: finished saving model to /kaggle/working/ai_classification/models/tf_cnn_face_model_v20260413_144919/best.keras
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 897ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0067 - learning_rate: 2.5000e-05
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.9986 - loss: 0.0034
# Epoch 29: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 36s 827ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0050 - learning_rate: 2.5000e-05
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 30: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 37s 848ms/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0035 - learning_rate: 2.5000e-05
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 31: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 865ms/step - accuracy: 1.0000 - loss: 6.5637e-04 - val_accuracy: 1.0000 - val_loss: 0.0030 - learning_rate: 2.5000e-05
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 1.0000 - loss: 4.0214e-04
# Epoch 32: val_accuracy did not improve from 1.00000
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 37s 853ms/step - accuracy: 1.0000 - loss: 4.2700e-04 - val_accuracy: 1.0000 - val_loss: 0.0025 - learning_rate: 2.5000e-05
# Epoch 33/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 1.0000 - loss: 3.1070e-04
# Epoch 33: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 884ms/step - accuracy: 1.0000 - loss: 4.1272e-04 - val_accuracy: 1.0000 - val_loss: 0.0022 - learning_rate: 1.2500e-05
# Epoch 34/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 34: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 885ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0020 - learning_rate: 1.2500e-05
# Epoch 35/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - accuracy: 1.0000 - loss: 5.8727e-04
# Epoch 35: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 38s 874ms/step - accuracy: 1.0000 - loss: 6.9968e-04 - val_accuracy: 1.0000 - val_loss: 0.0018 - learning_rate: 1.2500e-05
# Epoch 36/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 36: val_accuracy did not improve from 1.00000
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 886ms/step - accuracy: 1.0000 - loss: 7.8773e-04 - val_accuracy: 1.0000 - val_loss: 0.0016 - learning_rate: 1.2500e-05
# Epoch 37/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 37: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 878ms/step - accuracy: 1.0000 - loss: 5.2330e-04 - val_accuracy: 1.0000 - val_loss: 0.0014 - learning_rate: 6.2500e-06
# Epoch 38/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 1.0000 - loss: 2.4900e-04
# Epoch 38: val_accuracy did not improve from 1.00000
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 39s 884ms/step - accuracy: 1.0000 - loss: 2.9645e-04 - val_accuracy: 1.0000 - val_loss: 0.0013 - learning_rate: 6.2500e-06
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
#
# Evaluating on Test set...
# 1/1 - 2s - 2s/step
# 1/1 - 0s - 463ms/step
# 1/1 - 0s - 459ms/step
# 1/1 - 0s - 467ms/step
# 1/1 - 0s - 454ms/step
# 1/1 - 0s - 469ms/step
# 1/1 - 0s - 483ms/step
# 1/1 - 1s - 611ms/step
# 1/1 - 0s - 453ms/step
# 1/1 - 2s - 2s/step
#
# === Confusion Matrix ===
# [[75  0  0  0]
#  [ 0 75  0  0]
#  [ 0  0 75  0]
#  [ 0  0  0 75]]
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#        Khang     1.0000    1.0000    1.0000        75
#         Kien     1.0000    1.0000    1.0000        75
#         Phuc     1.0000    1.0000    1.0000        75
#           Tu     1.0000    1.0000    1.0000        75
#
#     accuracy                         1.0000       300
#    macro avg     1.0000    1.0000    1.0000       300
# weighted avg     1.0000    1.0000    1.0000       300
#
#  Quantization...
# python src/train/quantization.py --version 20260413_144919
# Input size loaded: (160, 160)
# Quantization to INT8...
# Saved artifact at '/tmp/tmp1vaf0lj_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138541822171408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822174096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822173520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822172560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822174864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822175056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822173904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822174672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822175632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822173136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822175440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822176784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822176400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822175824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822173712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822177552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822177360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822176208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822178128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822174288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822179280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822179472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822178704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822176976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822178320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822177936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822177744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822178896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822180432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822179856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822180048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822179664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822181200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822180624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822177168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822180816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822181008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822180240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541822179088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761036752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761037904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761037712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761037328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761038480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761038864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761039056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761038096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761038672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761039632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761037520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761039248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761039440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761036944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761040592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761040016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761040208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761040400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761036560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761041552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761040976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761041168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761041360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761038288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761042512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761041936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761042128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761042320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761039824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761043472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761042896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761043088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761043280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761040784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761044432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761043856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761044048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761044240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761041744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761045392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761044816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761045008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761045200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761042704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761046352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761045776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761045968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761046160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761043664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761047312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761046736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761046928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761047120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761044624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761048272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761047696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761047888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761048080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761045584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761049232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761048656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761048848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761049040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761046544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761050192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761049616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761049808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761050000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761047504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761051152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761050576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761050768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761050960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761048464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761052112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761051536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761049424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761052304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761051728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761052496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761051920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759874064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759873488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761050384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541761051344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759873104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759874256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759874448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759873872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759875408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759874832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759875024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759875216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759873296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759876368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759875792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759875984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759876176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759873680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759877328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759876752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759876944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759877136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759874640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759878288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759877712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759877904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759878096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759875600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759879248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759878672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759878864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759879056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759876560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759879632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759879824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759880016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759877520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759881168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759880592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759880784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759880976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759878480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759881552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759881936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759879440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759883088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759882512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759882704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759880400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759883472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759883856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759881360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759884432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759884816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759882320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759885968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759885392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759885584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759885776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759883280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759886928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759886352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759886544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759886736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759887888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759887312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759887696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759885200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759888848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759888272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759886160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759889040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760659536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759887120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541759888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760660112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760661840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760662992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138541760670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1776093325.324119    1183 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1776093325.324197    1183 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1776093325.536845    1183 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# Traceback (most recent call last):
#   File "/kaggle/working/ai_classification/src/train/quantization.py", line 71, in <module>
#     main()
#   File "/kaggle/working/ai_classification/src/train/quantization.py", line 64, in main
#     tflite_int8 = converter.convert()
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 1254, in wrapper
#     return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 1206, in _convert_and_export_metrics
#     result = convert_func(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 1772, in convert
#     saved_model_convert_result = self._convert_as_saved_model()
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 1753, in _convert_as_saved_model
#     return super(TFLiteKerasModelConverterV2, self).convert(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 1498, in convert
#     return self._optimize_tflite_model(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_phase.py", line 215, in wrapper
#     raise error from None  # Re-throws the exception.
#     ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_phase.py", line 205, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 1150, in _optimize_tflite_model
#     model = self._quantize(
#             ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/lite.py", line 761, in _quantize
#     calibrated = calibrate_quantize.calibrate(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_phase.py", line 215, in wrapper
#     raise error from None  # Re-throws the exception.
#     ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert_phase.py", line 205, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/optimize/calibrator.py", line 258, in calibrate
#     self._feed_tensors(dataset_gen, resize_input=True)
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/optimize/calibrator.py", line 101, in _feed_tensors
#     for sample in dataset_gen():
#                   ^^^^^^^^^^^^^
#   File "/kaggle/working/ai_classification/src/train/quantization.py", line 32, in rep_data_gen
#     paths = [p for p in REP_DIR.iterdir() if p.is_file() and p.suffix.lower() in valid_exts]
#                         ^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 1056, in iterdir
#     for name in os.listdir(self):
#                 ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/ai_classification/data/processed'
# make: *** [makefile:17: quantize] Error 1
