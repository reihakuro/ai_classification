# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


if not os.path.exists("ai_classification"):

    # !git clone -q https://github.com/reihakuro/ai_classification.git --quiet

# %cd /kaggle/working/ai_classification --quiet


# !mkdir -p data/raw --quiet


# !cp -q -r /kaggle/input/datasets/trungkientrungkien/faceclassificationdataset/data/raw/. data/raw/ --quiet


# !pip install -qq -r requirements.txt --quiet

# !make all
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/ai_classification --quiet'
# /kaggle/working
# mkdir: unrecognized option '--quiet'
# Try 'mkdir --help' for more information.
# cp: invalid option -- 'q'
# Try 'cp --help' for more information.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# make: *** No rule to make target 'all'.  Stop.
