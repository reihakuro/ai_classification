# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# !echo "--- START LOG ---" > /kaggle/working/logs.txt

if not os.path.exists("ai_classification"):
    # !git clone -q https://github.com/reihakuro/ai_classification.git > /dev/null 2>&1

# %cd /kaggle/working/ai_classification

# !mkdir -p data/raw > /dev/null 2>&1
# !cp -r /kaggle/input/datasets/trungkientrungkien/faceclassificationdataset/data/raw/. data/raw/ > /dev/null 2>&1
# !mkdir -p data/processed > /dev/null 2>&1
# !cp -r /kaggle/input/datasets/trungkientrungkien/faceclassificationdataset/data/processed/. data/processed/ > /dev/null 2>&1


# !pip install -qq -r requirements.txt > /dev/null 2>&1

print("Start running")

# !make all >> ../logs.txt 2>&1

print("Run successfully, check log at /kaggle/working/logs.txt")
# Out:
# /kaggle/working/ai_classification
# Start running
# Run successfully, check log at /kaggle/working/logs.txt
