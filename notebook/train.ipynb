# %%
import os

# !git clone https://github.com/reihakuro/ai_classification.git
# %cd /kaggle/working/ai_classification

# !mkdir -p data/raw

# !cp -r /kaggle/input/faceclassificationdataset/data/raw/* data/raw/


# !pip install -r requirements.txt
# !make all
# Out:
# Cloning into 'ai_classification'...
# remote: Enumerating objects: 224, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 224 (delta 89), reused 174 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (224/224), 52.06 KiB | 1.41 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# /kaggle/working/ai_classification
# cp: cannot stat '/kaggle/input/faceclassificationdataset/data/raw/*': No such file or directory
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 2.5 MB/s eta 0:00:00
# ...
